# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\MUHAMMAD
# [nltk_data]     AHSAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# Sir ka task: Sentence ko words mein convert karna
my_text = "Ahsan has successfully set up Python, VS Code, and Tokenization."

# Tokenization process
my_tokens = word_tokenize(my_text)

# Result print karna
print("Original Sentence:", my_text)
print("List of Tokens:", my_tokens)
# Out:
# Original Sentence: Ahsan has successfully set up Python, VS Code, and Tokenization.
# List of Tokens: ['Ahsan', 'has', 'successfully', 'set', 'up', 'Python', ',', 'VS', 'Code', ',', 'and', 'Tokenization', '.']

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\MUHAMMAD
# [nltk_data]     AHSAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\MUHAMMAD
# [nltk_data]     AHSAN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\MUHAMMAD
# [nltk_data]     AHSAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\MUHAMMAD
# [nltk_data]     AHSAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print("Hello Ahsan! Jupyter is working.")
# Out:
# Hello Ahsan! Jupyter is working.
